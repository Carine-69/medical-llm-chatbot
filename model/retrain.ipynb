# %% [markdown]
# # Medical Chatbot Inference & Interface (using checkpoint-2000)
#
# This notebook demonstrates how to load your current best checkpoint and interact with your domain-specific chatbot. When you finish retraining, you can simply update the checkpoint path to use your best model.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

model_name = "Featherless-Chat-Models/Mistral-7B-Instruct-v0.2"

bnb_config = BitsAndBytesConfig(load_in_4bit=True)

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="cpu"
)

print("4-bit model downloaded.")
# Out:
# Loading weights: 100%|██████████| 291/291 [05:05<00:00,  1.05s/it, Materializing param=model.norm.weight]
# 4-bit model downloaded.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from transformers import AutoTokenizer, AutoModelForCausalLM, Trainer, TrainingArguments, DataCollatorForSeq2Seq
#       2 from proccess import formatted_ds, tokenize_row
# ----> 3 trainer.train(resume_from_checkpoint="./checkpoint-2000")
#
# NameError: name 'trainer' is not defined

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import PeftModel
import os
import torch
from proccess import formatted_ds

# Use the correct local checkpoint directory for tokenizer and adapter
ckpt_dir = os.path.abspath("./checkpoint-2000")

# Load tokenizer from local checkpoint directory
tokenizer = AutoTokenizer.from_pretrained(
    ckpt_dir,
    local_files_only=True
)

# Load base model (quantized, force CPU to avoid OOM)
bnb_config = BitsAndBytesConfig(load_in_4bit=True, llm_int8_enable_fp32_cpu_offload=True)
base_model = AutoModelForCausalLM.from_pretrained(
    "Featherless-Chat-Models/Mistral-7B-Instruct-v0.2",
    device_map="cpu",  # Force CPU to avoid GPU OOM
    quantization_config=bnb_config,
    local_files_only=True
)

# Load LoRA adapter from local checkpoint directory
model = PeftModel.from_pretrained(
    base_model,
    ckpt_dir,
    local_files_only=True
)

# # Move model to GPU if available
# device = "cuda" if torch.cuda.is_available() else "cpu"
# model = model.to(device)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/utils/hub.py:419, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     417 if len(full_filenames) == 1:
#     418     # This is slightly better for only 1 file
# --> 419     hf_hub_download(
#     420         path_or_repo_id,
#     421         filenames[0],
#     422         subfolder=None if len(subfolder) == 0 else subfolder,
#     423         repo_type=repo_type,
#     424         revision=revision,
#     425         cache_dir=cache_dir,
#     426         user_agent=user_agent,
#     427         force_download=force_download,
#     428         proxies=proxies,
#     429         token=token,
#     430         local_files_only=local_files_only,
#     431     )
#     432 else:
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:85, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84     if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:129, in validate_repo_id(repo_id)
#     128 if repo_id.count("/") > 1:
# --> 129     raise HFValidationError(
#     130         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     131         f" '{repo_id}'. Use `repo_type` argument if needed."
#     132     )
#     134 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/home/umugabekazi/Desktop/health-care_chatbot/model/checkpoint-2000'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:616, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     615 try:
# --> 616     config = AutoConfig.from_pretrained(
#     617         pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     618     )
#     619 except Exception:
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/models/auto/configuration_auto.py:1376, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1374 code_revision = kwargs.pop("code_revision", None)
# -> 1376 config_dict, unused_kwargs = PreTrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1377 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/configuration_utils.py:569, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     568 # Get config dict associated with the base config file
# --> 569 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     570 if config_dict is None:
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/configuration_utils.py:624, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     622 try:
#     623     # Load from local folder or from cache or download from model Hub and cache
# --> 624     resolved_config_file = cached_file(
#     625         pretrained_model_name_or_path,
#     626         configuration_file,
#     627         cache_dir=cache_dir,
#     628         force_download=force_download,
#     629         proxies=proxies,
#     630         local_files_only=local_files_only,
#     631         token=token,
#     632         user_agent=user_agent,
#     633         revision=revision,
#     634         subfolder=subfolder,
#     635         _commit_hash=commit_hash,
#     636     )
#     637     if resolved_config_file is None:
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/utils/hub.py:276, in cached_file(path_or_repo_id, filename, **kwargs)
#     226 """
#     227 Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     228
#    (...)    274 ```
#     275 """
# --> 276 file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     277 file = file[0] if file is not None else file
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/utils/hub.py:468, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     467 elif isinstance(e, ValueError):
# --> 468     raise OSError(f"{e}") from e
#     470 # Now we try to recover if we can find all files correctly in the cache
#
# OSError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/home/umugabekazi/Desktop/health-care_chatbot/model/checkpoint-2000'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# HFValidationError                         Traceback (most recent call last)
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/utils/hub.py:419, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     417 if len(full_filenames) == 1:
#     418     # This is slightly better for only 1 file
# --> 419     hf_hub_download(
#     420         path_or_repo_id,
#     421         filenames[0],
#     422         subfolder=None if len(subfolder) == 0 else subfolder,
#     423         repo_type=repo_type,
#     424         revision=revision,
#     425         cache_dir=cache_dir,
#     426         user_agent=user_agent,
#     427         force_download=force_download,
#     428         proxies=proxies,
#     429         token=token,
#     430         local_files_only=local_files_only,
#     431     )
#     432 else:
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:85, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84     if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:129, in validate_repo_id(repo_id)
#     128 if repo_id.count("/") > 1:
# --> 129     raise HFValidationError(
#     130         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     131         f" '{repo_id}'. Use `repo_type` argument if needed."
#     132     )
#     134 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/home/umugabekazi/Desktop/health-care_chatbot/model/checkpoint-2000'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 11
#       8 ckpt_dir = os.path.abspath("./checkpoint-2000")
#      10 # Load tokenizer from local checkpoint directory
# ---> 11 tokenizer = AutoTokenizer.from_pretrained(
#      12     ckpt_dir,
#      13     local_files_only=True
#      14 )
#      16 # Load base model (quantized, force CPU to avoid OOM)
#      17 bnb_config = BitsAndBytesConfig(load_in_4bit=True, llm_int8_enable_fp32_cpu_offload=True)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:620, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     616         config = AutoConfig.from_pretrained(
#     617             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     618         )
#     619     except Exception:
# --> 620         config = PreTrainedConfig.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     622 config_model_type = config.model_type
#     624 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/configuration_utils.py:531, in PreTrainedConfig.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#     528 kwargs["local_files_only"] = local_files_only
#     529 kwargs["revision"] = revision
# --> 531 config_dict, kwargs = cls.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     532 if cls.base_config_key and cls.base_config_key in config_dict:
#     533     config_dict = config_dict[cls.base_config_key]
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/configuration_utils.py:569, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     567 original_kwargs = copy.deepcopy(kwargs)
#     568 # Get config dict associated with the base config file
# --> 569 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     570 if config_dict is None:
#     571     return {}, kwargs
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/configuration_utils.py:624, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     620 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     622 try:
#     623     # Load from local folder or from cache or download from model Hub and cache
# --> 624     resolved_config_file = cached_file(
#     625         pretrained_model_name_or_path,
#     626         configuration_file,
#     627         cache_dir=cache_dir,
#     628         force_download=force_download,
#     629         proxies=proxies,
#     630         local_files_only=local_files_only,
#     631         token=token,
#     632         user_agent=user_agent,
#     633         revision=revision,
#     634         subfolder=subfolder,
#     635         _commit_hash=commit_hash,
#     636     )
#     637     if resolved_config_file is None:
#     638         return None, kwargs
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/utils/hub.py:276, in cached_file(path_or_repo_id, filename, **kwargs)
#     221 def cached_file(
#     222     path_or_repo_id: str | os.PathLike,
#     223     filename: str,
#     224     **kwargs,
#     225 ) -> str | None:
#     226     """
#     227     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     228
#    (...)    274     ```
#     275     """
# --> 276     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     277     file = file[0] if file is not None else file
#     278     return file
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/utils/hub.py:468, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     462     raise OSError(
#     463         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     464         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     465         "2) a previous download was canceled and the lock file needs manual removal."
#     466     ) from e
#     467 elif isinstance(e, ValueError):
# --> 468     raise OSError(f"{e}") from e
#     470 # Now we try to recover if we can find all files correctly in the cache
#     471 resolved_files = [
#     472     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision, repo_type)
#     473     for filename in full_filenames
#     474 ]
#
# OSError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/home/umugabekazi/Desktop/health-care_chatbot/model/checkpoint-2000'. Use `repo_type` argument if needed.

# %% [markdown]
# ## Try the chatbot: Single prompt example

# %%
# Set device for inference
device = "cuda" if torch.cuda.is_available() else "cpu"

prompt = "Instruction: What are the symptoms of diabetes? Question:  Response:"
inputs = tokenizer(prompt, return_tensors="pt")
inputs = {k: v.to(device) for k, v in inputs.items()}  # Move all tensors to the correct device
model = model.to(device)  # Ensure model is on the same device

outputs = model.generate(**inputs, max_new_tokens=128)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Instruction: What are the symptoms of diabetes? Question:  Response:  Diabetes is a chronic condition that affects the way your body processes blood sugar. Symptoms of diabetes can include frequent urination, excessive thirst, blurred vision, and increased hunger. These symptoms occur when the body is unable to produce or use insulin effectively, leading to high blood sugar levels. If left untreated, diabetes can cause a range of complications, including nerve damage, kidney damage, and cardiovascular disease. It is important to seek medical attention if you experience any of these symptoms, as early diagnosis and treatment can help prevent or manage the condition.

# %% [markdown]
# ## Interactive Chatbot Interface (Gradio)
# You can use this cell to launch a simple web interface for your chatbot. When you retrain and have a better checkpoint, just update `ckpt_dir` above.

# %%
import gradio as gr

def chat(query):
    # Wrap user input in the expected prompt format
    prompt = f"Instruction: {query} Response:"
    inputs = tokenizer(prompt, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    outputs = model.generate(**inputs, max_new_tokens=128)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    # Remove repeated question if present
    lines = response.split('\n')
    if lines[0].strip().lower().startswith(query.strip().lower()):
        response = '\n'.join(lines[1:]).strip()
    return response

gr.Interface(
    fn=chat,
    inputs=gr.Textbox(lines=2, label="Your medical question"),
    outputs=gr.Textbox(label="Chatbot Response"),
    title="Medical Chatbot",
    description="Ask a medical question and get a response from your fine-tuned model (checkpoint-2000)."
).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %% [markdown]
# ---
# **When you finish retraining:**
# - Change `ckpt_dir` to your best checkpoint directory (e.g., `./checkpoint-8000` or `./best_model`)
# - Re-run the notebook to use the improved model in the interface.
